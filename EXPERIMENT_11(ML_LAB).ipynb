# %% [markdown]
# <a href="https://colab.research.google.com/github/BayyaChinnu4202/EXPERIMENT-11-ML-LAB-/blob/main/EXPERIMENT_11(ML_LAB).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_blobs
data,labels=make_blobs(n_samples=300,n_features=2,centers=5,random_state=42)

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#           0         1
# 0 -0.623012  9.188864
# 1  0.543714  5.305206
# 2 -2.300334  7.054616
# 3  4.416416  2.687170
# 4 -3.837384  9.211147

# %%
X,_=make_blobs(n_samples=300,centers=5,cluster_std=0.60,random_state=0)

# %%
X_train,X_test=train_test_split(X,test_size=0.2,random_state=42)

# %%
kmeans=KMeans(n_clusters=5,random_state=42)
kmeans.fit(X_train)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
Y_train_pred=kmeans.predict(X_train)
Y_test_pred=kmeans.predict(X_test)

# %%
train_silhouette=silhouette_score(X_train,Y_train_pred)
test_silhouette=silhouette_score(X_test,Y_test_pred)

# %%
print(f"Training Silhouette Score: {train_silhouette:.2f}")
print(f"Testing Silhouette Score: {test_silhouette:.2f}")
# Out:
# Training Silhouette Score: 0.72
# Testing Silhouette Score: 0.71

# %%
plt.scatter(X_train[:,0],X_train[:,1],c=Y_train_pred,s=50,cmap='viridis',label='training data')
plt.scatter(X_test[:,0],X_test[:,1],c=Y_test_pred,s=50,cmap='plasma',label='testing data',alpha=0.5)
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=300,c='red',label='centroids')
plt.title('k_means clustering')
plt.legend()
plt.show()
